# %%
import pickle
import sys
import datetime
import time
import getpass

# %%
import Student
import Faculty
import Book

# %%
print('*'*38)
print('\033[1m'+'Welcome To Library')
print('*'*38)
print('\033[1m'+'Login')
for i in range(3):
    user = input('Enter Username: ')
    passw = getpass.getpass()        
    if user == 'naruto' and passw == 'hello123':
        print('Welcome ',user)
        while True:
            while True:
                print('*'*38)
                print('Press 1 : Student')
                print('Press 2 : Faculty')
                print('Press 3 : Book')
                print('Press 4 : Exit')
                choice = int(input('Enter Your Choice: '))
                if choice == 1:
                    print('*'*38)
                    print('Press 1 : Add Student Details')
                    print('Press 2 : Display Student Details')
                    print('Press 3 : Delete Student Details')
                    print('Press 4 : Update Student Details')
                    print('Press 5 : Issue Book')
                    print('Press 6 : Return Book')
                    print('Press 7 : Calculate Fine')
                    print('Press 8 : Main Menu')
                    ch = int(input('Enter Your Choice: '))
                    if ch == 1:
                        Student.AddStudent()
                    elif ch == 2:
                        Student.displayStudentList()
                    elif ch == 3:
                        Student.deleteStudent()
                    elif ch == 4:
                        Student.modifyStudent()
                    elif ch == 5:
                        Student.issue_Book()
                    elif ch == 6:
                        Student.return_Book()
                    elif ch == 7:
                        Student.calculateFine()
                    elif ch == 8:
                        break
                elif choice == 2:
                    print('*'*38)
                    print('Press 1 : Add Faculty Details')
                    print('Press 2 : Display Faculty Details')
                    print('Press 3 : Delete Faculty Details')
                    print('Press 4 : Issue Book')
                    print('Press 5 : Return Book')
                    print('Press 6 : Calculate Fine')
                    print('Press 7 : Main Menu')
                    ch = int(input('Enter Your Choice: '))
                    if ch == 1:
                        Faculty.AddFaculty()
                    elif ch == 2:
                        Faculty.displayFacultyList()
                    elif ch == 3:
                        Faculty.deleteFaculty()
                    elif ch == 4:
                        Faculty.issue_Faculty_Book()
                    elif ch == 5:
                        Faculty.returnFacultyBook()
                    elif ch == 6:
                        Faculty.calculateFine()
                    elif ch == 7:
                        break
                elif choice == 3:
                    print('*'*38)
                    print('Press 1 : Add Book to Library')
                    print('Press 2 : Display List of Books')
                    print('Press 3 : Add Copies of Book')
                    print('Press 4 : Display Book Details by isbn No')
                    print('Press 5 : Display Book Details by Book Name')
                    print('Press 6 : Display Book Details by Author')
                    print('Press 7 : Main Menu')
                    ch = int(input('Enter Your Choice: '))
                    if ch == 1:
                        Book.addNewBook()
                    elif ch == 2:
                        Book.displayBookList()
                    elif ch == 3:
                        Book.addCopies()
                    elif ch == 4:
                        Book.isbnDetail()
                    elif ch == 5:
                        Book.bookNameDetail()
                    elif ch == 6:
                        Book.authorDetails()
                    if ch == 7:
                        break
                else:
                    sys.exit(0)
    else:
        print(2-i,'attempts left')
# Out:
# **************************************
# Welcome To Library
# **************************************
# Login
# Enter Username: naruto
# ········
# Welcome  naruto
# **************************************
# Press 1 : Student
# Press 2 : Faculty
# Press 3 : Book
# Press 4 : Exit
# Enter Your Choice: 1
# **************************************
# Press 1 : Add Student Details
# Press 2 : Display Student Details
# Press 3 : Delete Student Details
# Press 4 : Update Student Details
# Press 5 : Issue Book
# Press 6 : Return Book
# Press 7 : Calculate Fine
# Press 8 : Main Menu
# Enter Your Choice: 2
# Enrollment of Student is:  20170187cs1234
# Name of Student is:  harshit
# Branch of Student is:  cs
# Semester of Student is:  5
# Date of Issue Book:  []
# Date for Returning Book:  []
# Book Issued:  []
# Fine Amount of Student is: Rs 0
# **************************************
# Press 1 : Student
# Press 2 : Faculty
# Press 3 : Book
# Press 4 : Exit
# Enter Your Choice: 1
# ...

# %%
def createBookFile():
    with open('ListOfBook.pkl','wb') as f:
        books = {'Algorithms and data structures':[{'Narshima':[1264587452151,10]},{'Balaguruswami':[1212587458651,10]}],
                 'Artificial intelligence':[{'Sahani':[5478541236525,10]},{'Balaguruswami':[5487412365214,10]}],
                 'Computational science':[{'Sahani':[5874123698521,10]},{'Balaguruswami':[8547412365896,10]}],
                 'Computer architecture':[{'Sahani':[1254963258965,10]},{'Balaguruswami':[8569874521236,10]}]}
        pickle.dump(books,f)
createBookFile()

# %%
def createFacultyFile():
    with open('ListOfFaculty.pkl','wb') as f:
        l = []
        pickle.dump(l,f)
createFacultyFile()

# %%
def createStudentFile():
    with open('ListOfStudent.pkl','wb') as f:
        l = []
        pickle.dump(l,f)
createStudentFile()
